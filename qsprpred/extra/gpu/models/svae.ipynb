# %% [markdown]
# 60
# 1 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 100, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8463713477851084
# 2 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 100, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8165467625899281
# 3 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 100, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8535885167464115
# 4 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 100, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.828436018957346
# 5 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8522402287893232
# 6 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8444444444444444
# 7 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.848780487804878
# 8 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8532818532818532
# 9 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8516377649325626
# 10 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8531073446327684
# 11 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8269040553907022
# 12 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.841796875
# 13 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8460038986354775
# 14 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8502879078694817
# 15 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8214285714285714
# 16 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8400392541707556
# 17 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 700, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8414872798434442
# 18 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 700, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8440545808966862
# 19 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 700, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8234126984126984
# 20 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.15, 'n_epochs': 700, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8242303872889771
# 21 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 100, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8444863336475024
# 22 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 100, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8049426301853486
# 23 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 100, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8527724665391969
# 24 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 100, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8246445497630331
# 25 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8544243577545195
# 26 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8439519852262235
# 27 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8499025341130604
# 28 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8543876567020251
# 29 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8508180943214629
# 30 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8493408662900188
# 31 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8288822947576657
# 32 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8466019417475729
# 33 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8460038986354775
# 34 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8522072936660269
# 35 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8218905472636816
# 36 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8420019627085378
# 37 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 700, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8411764705882353
# 38 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 700, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8443579766536965
# 39 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 700, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8225966303270565
# 40 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.2, 'n_epochs': 700, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8258706467661692
# 41 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 100, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8455743879472694
# 42 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 100, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7894736842105263
# 43 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 100, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8445297504798465
# 44 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 100, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8196114708603145
# 45 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8533333333333334
# 46 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8401826484018264
# 47 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.851063829787234
# 48 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8549471661863592
# 49 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8530259365994236
# 50 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8507042253521127
# 51 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8357915437561455
# 52 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8516003879728419
# 53 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8482490272373541
# 54 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8555133079847909
# 55 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8206144697720515
# 56 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8453201970443349
# 57 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 700, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8423114593535749
# 58 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 700, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8450433108758422
# 59 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 700, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8225966303270565
# 60 / 60
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.3, 'n_epochs': 700, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8305252725470763

# %%
test_par = {'weight_decay': 0.0001, 'patience': 100,
            'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8],
            'n_epochs': 500, 'dropout_frac': 0.28, 'act_fun': F.selu}
model_sts_3 = STFullyConnected(n_dim=dataset.X.shape[1],  # počet vstupních neuronů (počet deskriptorů)
    n_class=1,  # regresní úloha (1 výstup)
    gpus=[],
    device="cuda",
    batch_size=256,is_reg=False, **test_par)
model_sts_3.fit(dataset.X, dataset.y)
res = model_sts_3.predict(dataset.X_ind)
res = res >0.5
print(f1_score(res, dataset.y_ind))
