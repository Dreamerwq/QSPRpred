# %%
# !pip install qsprpred
# Out:
# Collecting qsprpred
#   Using cached qsprpred-3.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting parameterized (from qsprpred)
#   Using cached parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting pebble (from qsprpred)
#   Using cached pebble-5.1.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from qsprpred) (2.0.1)
# Collecting scikit-learn>=1.0.2 (from qsprpred)
#   Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting pandas>=1.2.2 (from qsprpred)
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting matplotlib>=2.0 (from qsprpred)
#   Downloading matplotlib-3.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting chembl-structure-pipeline>=1.2.0 (from qsprpred)
#   Using cached chembl_structure_pipeline-1.2.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting rdkit (from qsprpred)
#   Downloading rdkit-2024.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting optuna (from qsprpred)
#   Using cached optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting gitpython (from qsprpred)
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting xgboost (from qsprpred)
#   Using cached xgboost-3.0.0-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting boruta (from qsprpred)
#   Using cached Boruta-0.4.3-py3-none-any.whl.metadata (8.8 kB)
# Collecting tqdm (from qsprpred)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting ml2json (from qsprpred)
#   Using cached ml2json-0.4.0-py3-none-any.whl.metadata (44 kB)
# Collecting jsonpickle (from qsprpred)
#   Using cached jsonpickle-4.0.2-py3-none-any.whl.metadata (8.2 kB)
# Collecting papyrus-scripts (from qsprpred)
#   Using cached papyrus_scripts-2.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting gbmtsplits (from qsprpred)
#   Using cached gbmtsplits-0.0.8-py3-none-any.whl.metadata (45 kB)
# Collecting mlchemad (from qsprpred)
#   Using cached mlchemad-1.5.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting mols2grid (from qsprpred)
#   Using cached mols2grid-2.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: setuptools>=46.4.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from chembl-structure-pipeline>=1.2.0->qsprpred) (75.8.0)
# Collecting contourpy>=1.0.1 (from matplotlib>=2.0->qsprpred)
#   Downloading contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=2.0->qsprpred)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=2.0->qsprpred)
#   Downloading fonttools-4.56.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=2.0->qsprpred)
#   Downloading kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from matplotlib>=2.0->qsprpred) (24.2)
# Collecting pillow>=8 (from matplotlib>=2.0->qsprpred)
#   Downloading pillow-11.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=2.0->qsprpred)
#   Using cached pyparsing-3.2.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from matplotlib>=2.0->qsprpred) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from pandas>=1.2.2->qsprpred) (2025.1)
# Collecting tzdata>=2022.7 (from pandas>=1.2.2->qsprpred)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.6.0 (from scikit-learn>=1.0.2->qsprpred)
#   Downloading scipy-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=1.0.2->qsprpred)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.0.2->qsprpred)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting seaborn (from gbmtsplits->qsprpred)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pulp (from gbmtsplits->qsprpred)
#   Using cached pulp-3.1.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython->qsprpred)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting scikit-learn>=1.0.2 (from qsprpred)
#   Downloading scikit_learn-1.4.0-1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy (from qsprpred)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting ipywidgets<8,>=7 (from mols2grid->qsprpred)
#   Using cached ipywidgets-7.8.5-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=2.11.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from mols2grid->qsprpred) (3.1.6)
# Collecting alembic>=1.5.0 (from optuna->qsprpred)
#   Using cached alembic-1.15.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna->qsprpred)
#   Using cached colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting sqlalchemy>=1.4.2 (from optuna->qsprpred)
#   Downloading sqlalchemy-2.0.39-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: PyYAML in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from optuna->qsprpred) (6.0.2)
# Requirement already satisfied: requests in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from papyrus-scripts->qsprpred) (2.32.3)
# Collecting mordred (from papyrus-scripts->qsprpred)
#   Using cached mordred-1.2.0.tar.gz (128 kB)
#   Preparing metadata (setup.py) ... done
# Collecting swifter (from papyrus-scripts->qsprpred)
#   Using cached swifter-1.4.0.tar.gz (1.2 MB)
#   Preparing metadata (setup.py) ... done
# Collecting pystow (from papyrus-scripts->qsprpred)
#   Using cached pystow-0.7.0-py3-none-any.whl.metadata (17 kB)
# Collecting prodec (from papyrus-scripts->qsprpred)
#   Using cached prodec-1.0.2.post5-py3-none-any.whl.metadata (7.0 kB)
# Collecting Mako (from alembic>=1.5.0->optuna->qsprpred)
#   Using cached Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.12 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from alembic>=1.5.0->optuna->qsprpred) (4.12.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->qsprpred)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: comm>=0.1.3 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipywidgets<8,>=7->mols2grid->qsprpred) (0.2.2)
# Collecting ipython-genutils~=0.2.0 (from ipywidgets<8,>=7->mols2grid->qsprpred)
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: traitlets>=4.3.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipywidgets<8,>=7->mols2grid->qsprpred) (5.14.3)
# Collecting widgetsnbextension~=3.6.10 (from ipywidgets<8,>=7->mols2grid->qsprpred)
#   Using cached widgetsnbextension-3.6.10-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: ipython>=4.0.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipywidgets<8,>=7->mols2grid->qsprpred) (9.0.2)
# Collecting jupyterlab-widgets<3,>=1.0.0 (from ipywidgets<8,>=7->mols2grid->qsprpred)
#   Using cached jupyterlab_widgets-1.1.11-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jinja2>=2.11.0->mols2grid->qsprpred) (3.0.2)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.0->qsprpred) (1.17.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.4.2->optuna->qsprpred)
#   Downloading greenlet-3.1.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting networkx==2.* (from mordred->papyrus-scripts->qsprpred)
#   Using cached networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting orjson (from prodec->papyrus-scripts->qsprpred)
#   Downloading orjson-3.10.16-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Requirement already satisfied: psutil in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from prodec->papyrus-scripts->qsprpred) (5.9.0)
# Collecting click (from pystow->papyrus-scripts->qsprpred)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from requests->papyrus-scripts->qsprpred) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from requests->papyrus-scripts->qsprpred) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from requests->papyrus-scripts->qsprpred) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from requests->papyrus-scripts->qsprpred) (2025.1.31)
# Collecting dask>=2.10.0 (from dask[dataframe]>=2.10.0->swifter->papyrus-scripts->qsprpred)
#   Using cached dask-2025.3.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting cloudpickle>=3.0.0 (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->papyrus-scripts->qsprpred)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->papyrus-scripts->qsprpred) (2024.12.0)
# Collecting partd>=1.4.0 (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->papyrus-scripts->qsprpred)
#   Using cached partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting toolz>=0.10.0 (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->papyrus-scripts->qsprpred)
#   Using cached toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->papyrus-scripts->qsprpred) (8.6.1)
# Collecting pyarrow>=14.0.1 (from dask[dataframe]>=2.10.0->swifter->papyrus-scripts->qsprpred)
#   Downloading pyarrow-19.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: decorator in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (2.19.1)
# Requirement already satisfied: stack_data in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (0.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (7.3.3)
# Requirement already satisfied: zipp>=3.20 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->papyrus-scripts->qsprpred) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (0.8.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.6 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (4.3.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (6.4.2)
# Collecting locket (from partd>=1.4.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->papyrus-scripts->qsprpred)
#   Using cached locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from stack_data->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from stack_data->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (3.0.0)
# Requirement already satisfied: pure_eval in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from stack_data->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid->qsprpred) (0.2.3)
# Requirement already satisfied: anyio>=3.1.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyterlab<4.4,>=4.3.6->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyterlab<4.4,>=4.3.6->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyterlab<4.4,>=4.3.6->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyterlab<4.4,>=4.3.6->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (4.23.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.8.11)
# Requirement already satisfied: nest-asyncio in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.6.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (4.3.7)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (6.2.0)
# Requirement already satisfied: defusedxml in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.5.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2.21.1)
# Requirement already satisfied: webencodings in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.4.0)
# Requirement already satisfied: fqdn in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.5.1)
# Requirement already satisfied: isoduration in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (3.0.0)
# Requirement already satisfied: uri-template in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2.5)
# Requirement already satisfied: pycparser in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid->qsprpred) (2.9.0.20241206)
# Using cached qsprpred-3.2.1-py3-none-any.whl (3.8 MB)
# Using cached chembl_structure_pipeline-1.2.2-py3-none-any.whl (17 kB)
# Downloading matplotlib-3.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 11.1 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 35.4 MB/s eta 0:00:0000:01
# Downloading rdkit-2024.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 1.4 MB/s eta 0:00:0000:0100:020m
# Using cached Boruta-0.4.3-py3-none-any.whl (57 kB)
# Using cached gbmtsplits-0.0.8-py3-none-any.whl (45 kB)
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Using cached jsonpickle-4.0.2-py3-none-any.whl (46 kB)
# Using cached ml2json-0.4.0-py3-none-any.whl (44 kB)
# Downloading scikit_learn-1.4.0-1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 46.9 MB/s eta 0:00:0000:01
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 73.4 MB/s eta 0:00:00:00:01
# Using cached mlchemad-1.5.2-py3-none-any.whl (314 kB)
# Using cached mols2grid-2.0.0-py3-none-any.whl (107 kB)
# Using cached optuna-4.2.1-py3-none-any.whl (383 kB)
# Using cached papyrus_scripts-2.1.1-py3-none-any.whl (86 kB)
# Using cached parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Using cached pebble-5.1.1-py3-none-any.whl (34 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached xgboost-3.0.0-py3-none-manylinux2014_x86_64.whl (4.9 MB)
# Using cached alembic-1.15.1-py3-none-any.whl (231 kB)
# Downloading contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 41.9 MB/s eta 0:00:00
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached ipywidgets-7.8.5-py2.py3-none-any.whl (124 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 14.9 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 34.4 MB/s eta 0:00:00
# Using cached pyparsing-3.2.2-py3-none-any.whl (111 kB)
# Downloading scipy-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 78.8 MB/s eta 0:00:00:00:01
# Downloading sqlalchemy-2.0.39-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 37.2 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached colorlog-6.9.0-py3-none-any.whl (11 kB)
# Using cached networkx-2.8.8-py3-none-any.whl (2.0 MB)
# Using cached prodec-1.0.2.post5-py3-none-any.whl (53 kB)
# Using cached pulp-3.1.1-py3-none-any.whl (16.4 MB)
# Using cached pystow-0.7.0-py3-none-any.whl (38 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached dask-2025.3.0-py3-none-any.whl (1.4 MB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Downloading greenlet-3.1.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (602 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.4/602.4 kB 5.3 MB/s eta 0:00:00
# Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached jupyterlab_widgets-1.1.11-py3-none-any.whl (246 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Using cached widgetsnbextension-3.6.10-py2.py3-none-any.whl (1.6 MB)
# Using cached Mako-1.3.9-py3-none-any.whl (78 kB)
# Downloading orjson-3.10.16-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (132 kB)
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Using cached partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading pyarrow-19.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 2.0 MB/s eta 0:00:0000:0100:01m
# Using cached toolz-1.0.0-py3-none-any.whl (56 kB)
# Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Building wheels for collected packages: mordred, swifter
#   Building wheel for mordred (setup.py) ... done
#   Created wheel for mordred: filename=mordred-1.2.0-py3-none-any.whl size=176774 sha256=ae51f6238601a7e7fd5f2d996c3007304646ac114def2e74dfde20631b1d81b9
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/8b/30/0b/84e3f6775306e74cf5957ee4d16b10bf3927dcec44cc23d5f2
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16558 sha256=dc1b65797aaa79ef7a412f80b849b16c993add02b19a011eeb82ef5fe78e6fac
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/ef/7f/bd/9bed48f078f3ee1fa75e0b29b6e0335ce1cb03a38d3443b3a3
# Successfully built mordred swifter
# Installing collected packages: ipython-genutils, tzdata, tqdm, toolz, threadpoolctl, smmap, pyparsing, pyarrow, pulp, pillow, pebble, parameterized, orjson, numpy, networkx, Mako, locket, kiwisolver, jupyterlab-widgets, jsonpickle, joblib, greenlet, fonttools, cycler, colorlog, cloudpickle, click, sqlalchemy, scipy, rdkit, pystow, partd, pandas, mordred, gitdb, contourpy, xgboost, scikit-learn, prodec, matplotlib, gitpython, dask, chembl-structure-pipeline, alembic, seaborn, optuna, mlchemad, ml2json, boruta, gbmtsplits, swifter, papyrus-scripts, widgetsnbextension, ipywidgets, mols2grid, qsprpred
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.1
#     Uninstalling numpy-2.0.1:
#       Successfully uninstalled numpy-2.0.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
# Successfully installed Mako-1.3.9 alembic-1.15.1 boruta-0.4.3 chembl-structure-pipeline-1.2.2 click-8.1.8 cloudpickle-3.1.1 colorlog-6.9.0 contourpy-1.3.1 cycler-0.12.1 dask-2025.3.0 fonttools-4.56.0 gbmtsplits-0.0.8 gitdb-4.0.12 gitpython-3.1.44 greenlet-3.1.1 ipython-genutils-0.2.0 ipywidgets-7.8.5 joblib-1.4.2 jsonpickle-4.0.2 jupyterlab-widgets-1.1.11 kiwisolver-1.4.8 locket-1.0.0 matplotlib-3.10.1 ml2json-0.4.0 mlchemad-1.5.2 mols2grid-2.0.0 mordred-1.2.0 networkx-2.8.8 numpy-1.26.4 optuna-4.2.1 orjson-3.10.16 pandas-2.2.3 papyrus-scripts-2.1.1 parameterized-0.9.0 partd-1.4.2 pebble-5.1.1 pillow-11.1.0 prodec-1.0.2.post5 pulp-3.1.1 pyarrow-19.0.1 pyparsing-3.2.2 pystow-0.7.0 qsprpred-3.2.1 rdkit-2024.3.2 scikit-learn-1.4.0 scipy-1.15.2 seaborn-0.13.2 smmap-5.0.2 sqlalchemy-2.0.39 swifter-1.4.0 threadpoolctl-3.6.0 toolz-1.0.0 tqdm-4.67.1 tzdata-2025.2 widgetsnbextension-3.6.10 xgboost-3.0.0

# %%
# Out:
# /home/ubuntu/miniconda3/lib/python3.12/site-packages/xgboost/core.py:377: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc >= 2.28) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
import os
import qsprpred

from qsprpred.extra.gpu.models.neural_network import STFullyConnected

from qsprpred.data import QSPRDataset, RandomSplit
from qsprpred.data.descriptors.fingerprints import MorganFP

os.makedirs("tutorial_output_test/data", exist_ok=True)

# Create dataset
dataset = QSPRDataset.fromTableFile(
    filename="../../../../tutorials/tutorial_data/A2A_LIGANDS.tsv",
    store_dir="tutorial_output_test/data",
    name="MonitoringTutorialDataset",
    target_props=[{"name": "pchembl_value_Mean", "task": "SINGLECLASS", "th": [6.5]}],
    random_state=42
)
# Out:
# /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages/xgboost/core.py:377: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc >= 2.28) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
display(dataset.df)
# Out:
#                                                                            SMILES  \
# QSPRID
# MonitoringTutorialDataset_0000  Cc1cc(C)n(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n...
# MonitoringTutorialDataset_0001  Nc1c(C(=O)Nc2ccc([N+](=O)[O-])cc2)sc2nc3c(cc12...
# MonitoringTutorialDataset_0002   O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
# MonitoringTutorialDataset_0003  CNC(=O)C12CC1C(n1cnc3c(NCc4cccc(Cl)c4)nc(C#CCC...
# MonitoringTutorialDataset_0004  CCCn1c(=O)c2c(nc3cc(OC)ccn32)n(CCCNC(=O)c2ccc(...
# ...                                                                           ...
# MonitoringTutorialDataset_4077     CNc1ncc(C(=O)NCc2ccc(OC)cc2)c2nc(-c3ccco3)nn12
# MonitoringTutorialDataset_4078         Nc1nc(-c2ccco2)c2ncn(C(=O)NCCc3ccccc3)c2n1
# MonitoringTutorialDataset_4079              Nc1nc(CSc2nnc(N)s2)nc(Nc2ccc(F)cc2)n1
# MonitoringTutorialDataset_4080      CCCOc1ccc(C=Cc2cc3c(c(=O)n(C)c(=O)n3C)n2C)cc1
# MonitoringTutorialDataset_4081           CCOC(=O)c1cnc(NCC(C)C)n2nc(-c3ccco3)nc12
#
#                                 pchembl_value_Mean    Year  \
# QSPRID
# MonitoringTutorialDataset_0000                True  2008.0
# MonitoringTutorialDataset_0001               False  2010.0
# MonitoringTutorialDataset_0002               False  2009.0
# MonitoringTutorialDataset_0003               False  2009.0
# MonitoringTutorialDataset_0004               False  2019.0
# ...                                            ...     ...
# MonitoringTutorialDataset_4077                True  2018.0
# MonitoringTutorialDataset_4078                True  2008.0
# MonitoringTutorialDataset_4079               False  2010.0
# MonitoringTutorialDataset_4080                True  2013.0
# MonitoringTutorialDataset_4081                True  2014.0
#
#                                                         QSPRID  \
# QSPRID
# MonitoringTutorialDataset_0000  MonitoringTutorialDataset_0000
# MonitoringTutorialDataset_0001  MonitoringTutorialDataset_0001
# MonitoringTutorialDataset_0002  MonitoringTutorialDataset_0002
# MonitoringTutorialDataset_0003  MonitoringTutorialDataset_0003
# MonitoringTutorialDataset_0004  MonitoringTutorialDataset_0004
# ...                                                        ...
# MonitoringTutorialDataset_4077  MonitoringTutorialDataset_4077
# MonitoringTutorialDataset_4078  MonitoringTutorialDataset_4078
# MonitoringTutorialDataset_4079  MonitoringTutorialDataset_4079
# MonitoringTutorialDataset_4080  MonitoringTutorialDataset_4080
# MonitoringTutorialDataset_4081  MonitoringTutorialDataset_4081
#
#                                 pchembl_value_Mean_original
# QSPRID
# MonitoringTutorialDataset_0000                         8.68
# MonitoringTutorialDataset_0001                         4.82
# MonitoringTutorialDataset_0002                         5.65
# MonitoringTutorialDataset_0003                         5.45
# MonitoringTutorialDataset_0004                         5.20
# ...                                                     ...
# MonitoringTutorialDataset_4077                         7.09
# MonitoringTutorialDataset_4078                         8.22
# MonitoringTutorialDataset_4079                         4.89
# MonitoringTutorialDataset_4080                         6.51
# MonitoringTutorialDataset_4081                         7.35
#
# [4082 rows x 5 columns]

# %%
# calculate compound features and split dataset into train and test
dataset.prepareDataset(
    split=RandomSplit(test_fraction=0.2, dataset=dataset),
    feature_calculators=[MorganFP(radius=3, nBits=2048)],
    recalculate_features=True,
)

dataset.getDF().head()
# Out:
#                                                                            SMILES  \
# QSPRID
# MonitoringTutorialDataset_0000  Cc1cc(C)n(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n...
# MonitoringTutorialDataset_0001  Nc1c(C(=O)Nc2ccc([N+](=O)[O-])cc2)sc2nc3c(cc12...
# MonitoringTutorialDataset_0002   O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
# MonitoringTutorialDataset_0003  CNC(=O)C12CC1C(n1cnc3c(NCc4cccc(Cl)c4)nc(C#CCC...
# MonitoringTutorialDataset_0004  CCCn1c(=O)c2c(nc3cc(OC)ccn32)n(CCCNC(=O)c2ccc(...
#
#                                 pchembl_value_Mean    Year  \
# QSPRID
# MonitoringTutorialDataset_0000                True  2008.0
# MonitoringTutorialDataset_0001               False  2010.0
# MonitoringTutorialDataset_0002               False  2009.0
# MonitoringTutorialDataset_0003               False  2009.0
# MonitoringTutorialDataset_0004               False  2019.0
#
#                                                         QSPRID  \
# QSPRID
# MonitoringTutorialDataset_0000  MonitoringTutorialDataset_0000
# MonitoringTutorialDataset_0001  MonitoringTutorialDataset_0001
# MonitoringTutorialDataset_0002  MonitoringTutorialDataset_0002
# MonitoringTutorialDataset_0003  MonitoringTutorialDataset_0003
# MonitoringTutorialDataset_0004  MonitoringTutorialDataset_0004
#
#                                 pchembl_value_Mean_original
# QSPRID
# MonitoringTutorialDataset_0000                         8.68
# MonitoringTutorialDataset_0001                         4.82
# MonitoringTutorialDataset_0002                         5.65
# MonitoringTutorialDataset_0003                         5.45
# MonitoringTutorialDataset_0004                         5.20

# %%
display("ahoj")
# Out:
# 'ahoj'

# %%
display(dataset.X)
# Out:
#                                 MorganFP_MorganFP_0  MorganFP_MorganFP_1  \
# QSPRID
# MonitoringTutorialDataset_0221                False                False
# MonitoringTutorialDataset_3644                False                False
# MonitoringTutorialDataset_2459                False                 True
# MonitoringTutorialDataset_1315                False                False
# MonitoringTutorialDataset_1017                False                False
# ...                                             ...                  ...
# MonitoringTutorialDataset_1130                False                False
# MonitoringTutorialDataset_1294                False                False
# MonitoringTutorialDataset_0860                False                False
# MonitoringTutorialDataset_3507                False                False
# MonitoringTutorialDataset_3174                False                False
#
#                                 MorganFP_MorganFP_2  MorganFP_MorganFP_3  \
# QSPRID
# MonitoringTutorialDataset_0221                False                False
# MonitoringTutorialDataset_3644                False                False
# MonitoringTutorialDataset_2459                False                False
# MonitoringTutorialDataset_1315                 True                False
# MonitoringTutorialDataset_1017                False                False
# ...                                             ...                  ...
# MonitoringTutorialDataset_1130                False                False
# MonitoringTutorialDataset_1294                False                 True
# MonitoringTutorialDataset_0860                False                False
# MonitoringTutorialDataset_3507                False                False
# MonitoringTutorialDataset_3174                False                False
#
#                                 MorganFP_MorganFP_4  MorganFP_MorganFP_5  \
# QSPRID
# MonitoringTutorialDataset_0221                False                False
# MonitoringTutorialDataset_3644                False                False
# MonitoringTutorialDataset_2459                False                False
# MonitoringTutorialDataset_1315                False                False
# MonitoringTutorialDataset_1017                False                False
# ...                                             ...                  ...
# MonitoringTutorialDataset_1130                False                False
# MonitoringTutorialDataset_1294                False                False
# MonitoringTutorialDataset_0860                False                False
# MonitoringTutorialDataset_3507                False                False
# MonitoringTutorialDataset_3174                False                False
#
#                                 MorganFP_MorganFP_6  MorganFP_MorganFP_7  \
# QSPRID
# MonitoringTutorialDataset_0221                False                False
# MonitoringTutorialDataset_3644                False                False
# MonitoringTutorialDataset_2459                False                False
# MonitoringTutorialDataset_1315                False                False
# MonitoringTutorialDataset_1017                False                False
# ...                                             ...                  ...
# MonitoringTutorialDataset_1130                False                False
# MonitoringTutorialDataset_1294                False                False
# MonitoringTutorialDataset_0860                False                False
# MonitoringTutorialDataset_3507                False                False
# MonitoringTutorialDataset_3174                False                 True
#
#                                 MorganFP_MorganFP_8  MorganFP_MorganFP_9  ...  \
# QSPRID                                                                    ...
# MonitoringTutorialDataset_0221                False                False  ...
# MonitoringTutorialDataset_3644                 True                False  ...
# MonitoringTutorialDataset_2459                False                False  ...
# MonitoringTutorialDataset_1315                False                False  ...
# MonitoringTutorialDataset_1017                False                False  ...
# ...                                             ...                  ...  ...
# MonitoringTutorialDataset_1130                False                False  ...
# MonitoringTutorialDataset_1294                False                False  ...
# MonitoringTutorialDataset_0860                False                False  ...
# MonitoringTutorialDataset_3507                False                False  ...
# MonitoringTutorialDataset_3174                False                False  ...
#
#                                 MorganFP_MorganFP_2038  \
# QSPRID
# MonitoringTutorialDataset_0221                    True
# MonitoringTutorialDataset_3644                   False
# MonitoringTutorialDataset_2459                   False
# MonitoringTutorialDataset_1315                    True
# MonitoringTutorialDataset_1017                    True
# ...                                                ...
# MonitoringTutorialDataset_1130                   False
# MonitoringTutorialDataset_1294                   False
# MonitoringTutorialDataset_0860                   False
# MonitoringTutorialDataset_3507                   False
# MonitoringTutorialDataset_3174                   False
#
#                                 MorganFP_MorganFP_2039  \
# QSPRID
# MonitoringTutorialDataset_0221                   False
# MonitoringTutorialDataset_3644                   False
# MonitoringTutorialDataset_2459                   False
# MonitoringTutorialDataset_1315                   False
# MonitoringTutorialDataset_1017                   False
# ...                                                ...
# MonitoringTutorialDataset_1130                   False
# MonitoringTutorialDataset_1294                   False
# MonitoringTutorialDataset_0860                   False
# MonitoringTutorialDataset_3507                   False
# MonitoringTutorialDataset_3174                   False
#
#                                 MorganFP_MorganFP_2040  \
# QSPRID
# MonitoringTutorialDataset_0221                   False
# MonitoringTutorialDataset_3644                   False
# MonitoringTutorialDataset_2459                   False
# MonitoringTutorialDataset_1315                   False
# MonitoringTutorialDataset_1017                   False
# ...                                                ...
# MonitoringTutorialDataset_1130                   False
# MonitoringTutorialDataset_1294                   False
# MonitoringTutorialDataset_0860                   False
# MonitoringTutorialDataset_3507                   False
# MonitoringTutorialDataset_3174                   False
#
#                                 MorganFP_MorganFP_2041  \
# QSPRID
# MonitoringTutorialDataset_0221                   False
# MonitoringTutorialDataset_3644                   False
# MonitoringTutorialDataset_2459                   False
# MonitoringTutorialDataset_1315                   False
# MonitoringTutorialDataset_1017                   False
# ...                                                ...
# MonitoringTutorialDataset_1130                   False
# MonitoringTutorialDataset_1294                   False
# MonitoringTutorialDataset_0860                   False
# MonitoringTutorialDataset_3507                   False
# MonitoringTutorialDataset_3174                   False
#
#                                 MorganFP_MorganFP_2042  \
# QSPRID
# MonitoringTutorialDataset_0221                   False
# MonitoringTutorialDataset_3644                   False
# MonitoringTutorialDataset_2459                   False
# MonitoringTutorialDataset_1315                   False
# MonitoringTutorialDataset_1017                    True
# ...                                                ...
# MonitoringTutorialDataset_1130                   False
# MonitoringTutorialDataset_1294                   False
# MonitoringTutorialDataset_0860                   False
# MonitoringTutorialDataset_3507                   False
# MonitoringTutorialDataset_3174                   False
#
#                                 MorganFP_MorganFP_2043  \
# QSPRID
# MonitoringTutorialDataset_0221                   False
# MonitoringTutorialDataset_3644                   False
# MonitoringTutorialDataset_2459                   False
# MonitoringTutorialDataset_1315                   False
# MonitoringTutorialDataset_1017                   False
# ...                                                ...
# MonitoringTutorialDataset_1130                   False
# MonitoringTutorialDataset_1294                   False
# MonitoringTutorialDataset_0860                   False
# MonitoringTutorialDataset_3507                   False
# MonitoringTutorialDataset_3174                   False
#
#                                 MorganFP_MorganFP_2044  \
# QSPRID
# MonitoringTutorialDataset_0221                   False
# MonitoringTutorialDataset_3644                   False
# MonitoringTutorialDataset_2459                   False
# MonitoringTutorialDataset_1315                   False
# MonitoringTutorialDataset_1017                   False
# ...                                                ...
# MonitoringTutorialDataset_1130                   False
# MonitoringTutorialDataset_1294                   False
# MonitoringTutorialDataset_0860                   False
# MonitoringTutorialDataset_3507                   False
# MonitoringTutorialDataset_3174                   False
#
#                                 MorganFP_MorganFP_2045  \
# QSPRID
# MonitoringTutorialDataset_0221                   False
# MonitoringTutorialDataset_3644                   False
# MonitoringTutorialDataset_2459                   False
# MonitoringTutorialDataset_1315                   False
# MonitoringTutorialDataset_1017                   False
# ...                                                ...
# MonitoringTutorialDataset_1130                   False
# MonitoringTutorialDataset_1294                    True
# MonitoringTutorialDataset_0860                   False
# MonitoringTutorialDataset_3507                   False
# MonitoringTutorialDataset_3174                   False
#
#                                 MorganFP_MorganFP_2046  MorganFP_MorganFP_2047
# QSPRID
# MonitoringTutorialDataset_0221                    True                   False
# MonitoringTutorialDataset_3644                   False                   False
# MonitoringTutorialDataset_2459                   False                   False
# MonitoringTutorialDataset_1315                   False                   False
# MonitoringTutorialDataset_1017                   False                   False
# ...                                                ...                     ...
# MonitoringTutorialDataset_1130                   False                    True
# MonitoringTutorialDataset_1294                   False                   False
# MonitoringTutorialDataset_0860                    True                    True
# MonitoringTutorialDataset_3507                   False                   False
# MonitoringTutorialDataset_3174                   False                   False
#
# [3265 rows x 2048 columns]

# %%
# Přidejte cestu k vašemu lokálnímu repozitáři
import sys
import os

# Přidání cesty k lokálnímu repozitáři na začátek sys.path
sys.path.insert(0, '/home/ubuntu/Bakalarka/QSPRpred')

# Zkontrolujte, zda je cesta v sys.path
print(sys.path)
# Out:
# ['/home/ubuntu/Bakalarka/QSPRpred', '/home/ubuntu/miniconda3/envs/bakalarka_env/lib/python311.zip', '/home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11', '/home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/lib-dynload', '', '/home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages']

# %%
from importlib import reload

# Znovu načtěte modul, abyste zajistili, že je správně importován
reload(sys.modules['qsprpred.extra.gpu.models.neural_network'])

# Znovu proveďte import
from qsprpred.extra.gpu.models.neural_network import STFullyConnected

# %%
os.chdir('/home/ubuntu/Bakalarka/QSPRpred')
print(os.getcwd())
# Out:
# /home/ubuntu/Bakalarka/QSPRpred

# %%
import sys
import importlib.util

# Přidání cesty k repozitáři do sys.path
sys.path.insert(0, '/home/ubuntu/Bakalarka/QSPRpred')

# Specifikujte cestu k souboru, který chcete importovat
module_path = '/home/ubuntu/Bakalarka/QSPRpred/qsprpred/extra/gpu/models/neural_network.py'
module_name = 'qsprpred.extra.gpu.models.neural_network'

# Načtěte modul z konkrétní cesty
spec = importlib.util.spec_from_file_location(module_name, module_path)
neural_network = importlib.util.module_from_spec(spec)
spec.loader.exec_module(neural_network)

# Nyní můžete používat třídu STFullyConnected
STFullyConnected = neural_network.STFullyConnected
# Out:
# lol

# %%
from torch.nn import functional as F

print("xd")
model_sts = STFullyConnected(
    n_dim=dataset.X.shape[1],  # počet vstupních neuronů (počet deskriptorů)
    n_class=1,  # regresní úloha (1 výstup)
    gpus=[],
    device="cuda",
    batch_size=256,
    patience=100,
    tol=1e-4,
    neuron_layers=[4000, 3000, 1000, 500, 200], #[3000, 1500, 500, 100]
    act_fun=F.selu,
    is_reg=False
)
model_sts.fit(dataset.X, dataset.y)
# Out:
# xd
# (STFullyConnected(
#    (layers): ModuleList(
#      (0): Linear(in_features=2048, out_features=4000, bias=True)
#      (1): Linear(in_features=4000, out_features=3000, bias=True)
#      (2): Linear(in_features=3000, out_features=1000, bias=True)
#      (3): Linear(in_features=1000, out_features=500, bias=True)
#      (4): Linear(in_features=500, out_features=200, bias=True)
#      (5): Linear(in_features=200, out_features=1, bias=True)
#    )
#    (dropout): Dropout(p=0.25, inplace=False)
#    (criterion): BCELoss()
#    (final_layer_activation): Sigmoid()
#  ),
#  0)

# %%
from sklearn.model_selection import ParameterGrid
from torch.nn import functional as F
from sklearn.metrics import f1_score
param_grid = ParameterGrid({
    "act_fun": [F.selu, F.elu, F.gelu, F.silu],
    "dropout_frac": [0, 0.05, 0.1],
    "patience": [100],
    "weight_decay": [1e-4],
    "n_epochs": [200, 350, 500],
    "neuron_layers": [[ 5000, 4096, 2048, 1024], [2048, 1024, 512, 256, 128, 64], [4096, 2048, 1024, 512, 256], [1024, 512, 256, 128, 64, 32, 16]],
})
print(len(param_grid))
i = 0
val_f1 = []
param_len = len(param_grid)
for param in param_grid:
    i += 1
    print(i, '/', param_len)
    model_sts = STFullyConnected(n_dim=dataset.X.shape[1],  # počet vstupních neuronů (počet deskriptorů)
    n_class=1,  # regresní úloha (1 výstup)
    gpus=[],
    device="cuda",
    batch_size=256,is_reg=False, **param)
    model_sts.fit(dataset.X, dataset.y)
    res = model_sts.predict(dataset.X_ind)
    res = res >0.5
    val_f1.append(f1_score(res, dataset.y_ind))
    print(param)
    print(f1_score(res, dataset.y_ind))
# Out:
# 144
# 1 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8408644400785854
# 2 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8507751937984496
# 3 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8529411764705882
# 4 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8389513108614233
# 5 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8260869565217391
# 6 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.84251968503937
# 7 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8272458045409674
# 8 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8498098859315589
# 9 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8257425742574257
# 10 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8305252725470763
# 11 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8189910979228486
# 12 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8491834774255523
# 13 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8431372549019608
# 14 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8507751937984496
# 15 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8501469147894222
# 16 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.839851024208566
# 17 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8260869565217391
# 18 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8385826771653543
# 19 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8272458045409674
# 20 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8490028490028491
# 21 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8245787908820614
# 22 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.83399209486166
# 23 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8222442899702085
# 24 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8519230769230769
# 25 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8428290766208252
# 26 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8532818532818532
# 27 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8512720156555773
# 28 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8372093023255814
# 29 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8272458045409674
# 30 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8411764705882353
# 31 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8265609514370664
# 32 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8500948766603416
# 33 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8245787908820614
# 34 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8374384236453202
# 35 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8222442899702085
# 36 / 144
# {'act_fun': <function selu at 0x7f1f3be4d580>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8508180943214629
# 37 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8423114593535749
# 38 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8472622478386167
# 39 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8494208494208494
# 40 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.7962489343563512
# 41 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8287401574803149
# 42 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8504854368932039
# 43 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8298918387413963
# 44 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8403669724770643
# 45 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8206144697720515
# 46 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8473581213307241
# 47 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8215353938185443
# 48 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.848314606741573
# 49 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8406647116324536
# 50 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8472622478386167
# 51 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8494208494208494
# 52 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.7962648556876061
# 53 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8279252704031466
# 54 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8516003879728419
# 55 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8315270935960591
# 56 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8403669724770643
# 57 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8206144697720515
# 58 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8434442270058709
# 59 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8207171314741036
# 60 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8475210477081384
# 61 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8390243902439024
# 62 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8456375838926175
# 63 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8502415458937198
# 64 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.7955894826123834
# 65 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8287401574803149
# 66 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8527131782945736
# 67 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.83399209486166
# 68 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8403669724770643
# 69 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8221343873517787
# 70 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.845703125
# 71 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8199004975124378
# 72 / 144
# {'act_fun': <function elu at 0x7f1f3be4d4e0>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8475210477081384
# 73 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8541062801932368
# 74 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.7681498829039812
# 75 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8437200383509108
# 76 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.0
# 77 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8399209486166008
# 78 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8154589371980676
# 79 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8513119533527697
# 80 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.7986906710310966
# 81 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8305252725470763
# 82 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8455598455598455
# 83 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8399209486166008
# 84 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8134135855546002
# 85 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8541062801932368
# 86 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.7681498829039812
# 87 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8426103646833013
# 88 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.0
# 89 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.841897233201581
# 90 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8166023166023166
# 91 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8510223953261928
# 92 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.7990115321252059
# 93 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.827037773359841
# 94 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8444444444444444
# 95 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8399209486166008
# 96 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8130921619293713
# 97 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8552123552123552
# 98 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.7681498829039812
# 99 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8426103646833013
# 100 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.0
# 101 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8402366863905325
# 102 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.813953488372093
# 103 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8532555879494655
# 104 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8003314001657
# 105 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8262164846077458
# 106 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8455598455598455
# 107 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8433497536945813
# 108 / 144
# {'act_fun': <built-in function gelu>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8141135972461274
# 109 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8529980657640233
# 110 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.789049919484702
# 111 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8454198473282443
# 112 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.0
# 113 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8399209486166008
# 114 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8279158699808795
# 115 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8504854368932039
# 116 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.7944535073409462
# 117 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8262164846077458
# 118 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8505747126436781
# 119 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.84251968503937
# 120 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.810671256454389
# 121 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8529980657640233
# 122 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.789049919484702
# 123 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8454198473282443
# 124 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.0
# 125 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.841897233201581
# 126 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8290353390639924
# 127 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8504854368932039
# 128 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.7970540098199672
# 129 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8253968253968254
# 130 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8497607655502393
# 131 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8436578171091446
# 132 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.05, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.8120689655172414
# 133 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8552123552123552
# 134 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.7881219903691814
# 135 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8454198473282443
# 136 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.0
# 137 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.84106614017769
# 138 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8279158699808795
# 139 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8516003879728419
# 140 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.7986852917009039
# 141 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [5000, 4096, 2048, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8253968253968254
# 142 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8486590038314177
# 143 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8431372549019608
# 144 / 144
# {'act_fun': <function silu at 0x7f1f3be4de40>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16], 'patience': 100, 'weight_decay': 0.0001}
# 0.811044003451251

# %%
from sklearn.metrics import f1_score

# print(model_sts.predict(dataset.X_ind))
res = model_sts.predict(dataset.X_ind)
res = res > 0.5
print(f1_score(dataset.y_ind, res))
# Out:
# 0.8505747126436781

# %%
import numpy as np


print(param_grid[np.argmax(val_f1)])
print(max(val_f1))
# Out:
# {'weight_decay': 0.0001, 'patience': 100, 'neuron_layers': [5000, 4096, 2048, 1024], 'n_epochs': 200, 'dropout_frac': 0.1, 'act_fun': <built-in function gelu>}
# 0.8552123552123552

# %%
from sklearn.model_selection import ParameterGrid
from torch.nn import functional as F
from sklearn.metrics import f1_score

param_grid_2 = ParameterGrid({
    "act_fun": [F.selu, F.elu, F.silu],
    "dropout_frac": [ 0.1, 0.2, 0.3, 0.4],
    "patience": [100],
    "weight_decay": [1e-4],
    "n_epochs": [1200, 350, 200, 500],
    "neuron_layers": [[ 5000, 1024], [2048, 1024, 512, 256, 128, 64, 32, 16, 8], [4096, 2048, 1024, 512, 256], [2048, 1024, 512, 256, 128, 64], [2048, 512, 512, 512, 126, 32]]
})
print(len(param_grid_2))
i = 0
val_f1_2 = []
param_len_2 = len(param_grid_2)
for param in param_grid_2:
    i += 1
    print(i, '/', param_len_2)
    model_sts_2 = STFullyConnected(n_dim=dataset.X.shape[1],  # počet vstupních neuronů (počet deskriptorů)
    n_class=1,  # regresní úloha (1 výstup)
    gpus=[],
    device="cuda",
    batch_size=256,is_reg=False, **param)
    model_sts_2.fit(dataset.X, dataset.y)
    res = model_sts_2.predict(dataset.X_ind)
    res = res >0.5
    val_f1_2.append(f1_score(res, dataset.y_ind))
    print(param)
    print(f1_score(res, dataset.y_ind))
# Out:
# 240
# 1 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8285431119920713
# 2 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8316633266533067
# 3 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8238805970149253
# 4 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.824
# 5 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8279252704031466
# 6 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8524590163934426
# 7 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8544423440453687
# 8 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8265609514370664
# 9 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8411764705882353
# 10 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.847424684159378
# 11 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8538681948424068
# 12 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8483720930232558
# 13 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8512720156555773
# 14 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8532818532818532
# 15 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8513513513513513
# 16 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.84765625
# 17 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.848893166506256
# 18 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8222442899702085
# 19 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8374384236453202
# 20 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8414872798434442
# 21 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8293650793650794
# 22 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8371174728529122
# 23 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8238805970149253
# 24 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8223552894211577
# 25 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8280632411067194
# 26 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8508180943214629
# 27 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8493408662900188
# 28 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8288822947576657
# 29 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8466019417475729
# 30 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8491295938104448
# 31 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8544243577545195
# 32 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8439519852262235
# 33 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8499025341130604
# 34 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8543876567020251
# 35 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8508180943214629
# 36 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8460038986354775
# 37 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8522072936660269
# 38 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8218905472636816
# 39 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8420019627085378
# 40 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8442703232125367
# 41 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8273809523809523
# 42 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8346303501945526
# 43 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8210735586481114
# 44 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8235294117647058
# 45 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8297029702970297
# 46 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8530259365994236
# 47 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8507042253521127
# 48 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8357915437561455
# 49 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8516003879728419
# 50 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.847424684159378
# 51 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8533333333333334
# 52 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8401826484018264
# 53 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.851063829787234
# 54 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8549471661863592
# 55 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8491834774255523
# 56 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8482490272373541
# 57 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8555133079847909
# 58 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8206144697720515
# 59 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8453201970443349
# 60 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8470588235294118
# 61 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8273809523809523
# 62 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8354430379746836
# 63 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8218905472636816
# 64 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8238805970149253
# 65 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8311944718657454
# 66 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8538461538461538
# 67 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8439519852262235
# 68 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8461538461538461
# 69 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8518877057115198
# 70 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8527131782945736
# 71 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8525214081826832
# 72 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.797588285960379
# 73 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8546679499518768
# 74 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.845933014354067
# 75 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8408007626310772
# 76 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8493683187560739
# 77 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8509840674789129
# 78 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8300395256916996
# 79 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8450980392156863
# 80 / 240
# {'act_fun': <function selu at 0x7fa779017a60>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8482490272373541
# 81 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8273809523809523
# 82 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8318227593152064
# 83 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8181818181818182
# 84 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8190854870775348
# 85 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8220255653883972
# 86 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8543876567020251
# 87 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8430066603235015
# 88 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.83399209486166
# 89 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8527131782945736
# 90 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8535402521823472
# 91 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8514285714285714
# 92 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8315412186379928
# 93 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8502415458937198
# 94 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8456375838926175
# 95 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8408007626310772
# 96 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8494208494208494
# 97 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8493683187560739
# 98 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8199004975124378
# 99 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.845703125
# 100 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8383349467570184
# 101 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8257425742574257
# 102 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8336673346693386
# 103 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8178217821782178
# 104 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8167330677290837
# 105 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8228346456692913
# 106 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8543876567020251
# 107 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8377358490566038
# 108 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8399209486166008
# 109 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8513119533527697
# 110 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.851063829787234
# 111 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8514285714285714
# 112 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.823321554770318
# 113 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.851063829787234
# 114 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8418024928092043
# 115 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8471035137701804
# 116 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8486017357762777
# 117 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8471953578336557
# 118 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8194444444444444
# 119 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8463035019455253
# 120 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.839458413926499
# 121 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8257425742574257
# 122 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8349900596421471
# 123 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8178217821782178
# 124 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8187250996015937
# 125 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.823992133726647
# 126 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8527430221366699
# 127 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8334901222953904
# 128 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8407517309594461
# 129 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8546511627906976
# 130 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8530259365994236
# 131 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8517110266159695
# 132 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8026868178001679
# 133 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8541062801932368
# 134 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8451242829827916
# 135 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8385269121813032
# 136 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8508180943214629
# 137 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8422071636011617
# 138 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8221343873517787
# 139 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.847424684159378
# 140 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8402710551790901
# 141 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8305252725470763
# 142 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8320158102766798
# 143 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8198019801980198
# 144 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8206144697720515
# 145 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.81648675171737
# 146 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8541266794625719
# 147 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8403669724770643
# 148 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8501469147894222
# 149 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8565928777670837
# 150 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8544061302681992
# 151 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8506184586108468
# 152 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 153 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8582449373191899
# 154 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8350612629594723
# 155 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8338028169014085
# 156 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8497109826589595
# 157 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8404966571155683
# 158 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8298918387413963
# 159 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8468992248062015
# 160 / 240
# {'act_fun': <function elu at 0x7fa7790179c0>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8474903474903475
# 161 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.83399209486166
# 162 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8177136972193615
# 163 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8227091633466136
# 164 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8369781312127237
# 165 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8422090729783037
# 166 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8555023923444977
# 167 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 168 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8516003879728419
# 169 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8279158699808795
# 170 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8181818181818182
# 171 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8358490566037736
# 172 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 173 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8454198473282443
# 174 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.7881219903691814
# 175 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.780952380952381
# 176 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8571428571428571
# 177 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 178 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8431372549019608
# 179 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8486590038314177
# 180 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.1, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.842911877394636
# 181 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8394088669950739
# 182 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.8246816846229187
# 183 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8230616302186878
# 184 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8384539147670962
# 185 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8436578171091446
# 186 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8535885167464115
# 187 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 188 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8524271844660194
# 189 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8229665071770335
# 190 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8166351606805293
# 191 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8342749529190208
# 192 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 193 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8451242829827916
# 194 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.7830940988835726
# 195 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.7790973871733967
# 196 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8574181117533719
# 197 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 198 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8450980392156863
# 199 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8486590038314177
# 200 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.2, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8421052631578947
# 201 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8402366863905325
# 202 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7738376674546887
# 203 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8255234297108675
# 204 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.841897233201581
# 205 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8431372549019608
# 206 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8530534351145038
# 207 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 208 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8527131782945736
# 209 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8213944603629417
# 210 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8105560791705938
# 211 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8327067669172933
# 212 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 213 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8424068767908309
# 214 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.7784810126582279
# 215 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.7717647058823529
# 216 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8552253116011506
# 217 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 218 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8411764705882353
# 219 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8478468899521531
# 220 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.3, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.842911877394636
# 221 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8385826771653543
# 222 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 223 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8278606965174129
# 224 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8400392541707556
# 225 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 1200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8429268292682927
# 226 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8530534351145038
# 227 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 228 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8557599225556631
# 229 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8136234626300851
# 230 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 350, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8070829450139795
# 231 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8330206378986866
# 232 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 233 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8408007626310772
# 234 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.7651632970451011
# 235 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.7621998450813323
# 236 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [5000, 1024], 'patience': 100, 'weight_decay': 0.0001}
# 0.8544061302681992
# 237 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64, 32, 16, 8], 'patience': 100, 'weight_decay': 0.0001}
# 0.7526717557251908
# 238 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'patience': 100, 'weight_decay': 0.0001}
# 0.8432327166504382
# 239 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [2048, 1024, 512, 256, 128, 64], 'patience': 100, 'weight_decay': 0.0001}
# 0.8446139180171592
# 240 / 240
# {'act_fun': <function silu at 0x7fa779024360>, 'dropout_frac': 0.4, 'n_epochs': 500, 'neuron_layers': [2048, 512, 512, 512, 126, 32], 'patience': 100, 'weight_decay': 0.0001}
# 0.8465204957102002

# %%
import numpy as np
print(param_grid_2[np.argmax(val_f1_2)])
print(max(val_f1_2))
# Out:
# {'weight_decay': 0.0001, 'patience': 100, 'neuron_layers': [4096, 2048, 1024, 512, 256], 'n_epochs': 200, 'dropout_frac': 0.4, 'act_fun': <function elu at 0x7fa7790179c0>}
# 0.8582449373191899

# %%
test_par = {'weight_decay': 0.0001, 'patience': 100, 
            'neuron_layers': [4096, 2048, 1024, 512, 256],
            'n_epochs': 200, 'dropout_frac': 0.41,
            'act_fun': F.elu}
model_sts_3 = STFullyConnected(n_dim=dataset.X.shape[1],  # počet vstupních neuronů (počet deskriptorů)
    n_class=1,  # regresní úloha (1 výstup)
    gpus=[],
    device="cuda",
    batch_size=256,is_reg=False, **test_par)
model_sts_3.fit(dataset.X, dataset.y)
res = model_sts_3.predict(dataset.X_ind)
res = res >0.5
print(f1_score(res, dataset.y_ind))
# Out:
# 0.8582449373191899

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(res, dataset.y_ind))
# Out:
# 0.8200734394124847

# %%
# Create model
from qsprpred.extra.gpu.models.dnn import DNNModel

os.makedirs("tutorial_output_test/models", exist_ok=True)
model = DNNModel(
    base_dir='tutorial_output_test/models',
    name='MonitoringTutorialModel',
    parameters=model_sts.get_params(),
    patience=3,
    tol=0.01,

)

model.initFromDataset(dataset)
print(model.parameters)
model.estimator = model_sts
display(type(model.estimator))
display(model.estimator)
# Out:
# lol
# lol
# lol
# {'act_fun': <function selu at 0x173ed9b20>, 'batch_size': 256, 'device': device(type='cpu'), 'dropout_frac': 0.25, 'gpus': [], 'is_reg': False, 'lr': 1e-05, 'n_class': 1, 'n_dim': 2048, 'n_epochs': 100, 'neuron_layers': [4000, 3000, 1000, 200], 'patience': 100, 'random_seed': 42, 'tol': 0.0001, 'weight_decay': 0}
# qsprpred.extra.gpu.models.neural_network.STFullyConnected
# STFullyConnected(
#   (layers): ModuleList(
#     (0): Linear(in_features=2048, out_features=4000, bias=True)
#     (1): Linear(in_features=4000, out_features=3000, bias=True)
#     (2): Linear(in_features=3000, out_features=1000, bias=True)
#     (3): Linear(in_features=1000, out_features=200, bias=True)
#     (4): Linear(in_features=200, out_features=1, bias=True)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (criterion): BCELoss()
#   (final_layer_activation): Sigmoid()
# )

# %%
from sklearn.metrics import accuracy_score
display(accuracy_score(dataset.y_ind, res))
# Out:
# 0.8078335373317014

# %%
from qsprpred.models import CrossValAssessor, TestSetAssessor

CrossValAssessor("f1")(model, dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 from qsprpred.models import CrossValAssessor, TestSetAssessor
# ----> 3 CrossValAssessor("f1")(model, dataset)
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/models/assessment/methods.py:212, in CrossValAssessor.__call__(self, model, ds, save, parameters, monitor, **kwargs)
#     210 # fit model
#     211 crossval_estimator = model.loadEstimator(evalparams)
# --> 212 model_fit = model.fit(
#     213     X_train,
#     214     y_train,
#     215     crossval_estimator,
#     216     self.mode,
#     217     monitor=monitor,
#     218     **kwargs,
#     219 )
#     220 # make predictions
#     221 if model.task.isRegression() or not self.useProba:
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/models/early_stopping.py:184, in early_stopping.<locals>.wrapper_fit(self, X, y, estimator, mode, split, monitor, **kwargs)
#     179 assert self.supportsEarlyStopping, (
#     180     "early_stopping decorator can only be used for models that support"
#     181     " early stopping."
#     182 )
#     183 self.earlyStopping.mode = mode if mode is not None else self.earlyStopping.mode
# --> 184 estimator, best_epoch = func(
#     185     self, X, y, estimator, mode, split, monitor, **kwargs
#     186 )
#     187 if self.earlyStopping.mode == EarlyStoppingMode.RECORDING:
#     188     self.earlyStopping.recordEpochs(best_epoch + 1)  # +1 for 0-indexing
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/extra/gpu/models/dnn.py:277, in DNNModel.fit(self, X, y, estimator, mode, split, monitor, **kwargs)
#     273 train_index, val_index = next(split.split(X, y))
#     274 monitor.onFitStart(
#     275     self, X[train_index, :], y[train_index], X[val_index, :], y[val_index]
#     276 )
# --> 277 estimator_fit = estimator.fit(
#     278     X[train_index, :],
#     279     y[train_index],
#     280     X[val_index, :],
#     281     y[val_index],
#     282     monitor=monitor,
#     283     **kwargs,
#     284 )
#     285 monitor.onFitEnd(estimator_fit[0], estimator_fit[1])
#     286 return estimator_fit
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/extra/gpu/models/neural_network.py:151, in Base.fit(self, X_train, y_train, X_valid, y_valid, monitor)
#     149 optimizer.zero_grad()
#     150 # predicted probability tensor
# --> 151 y_ = self(Xb, is_train=True)
#     152 # ignore all the NaN values
#     153 ix = yb == yb
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/extra/gpu/models/neural_network.py:493, in forward(self, X, is_train)
#     490     if is_train:
#     491         y = self.dropout(y)  # Apply dropout only during training
# --> 493 if self.is_reg:
#     494     # If regression, no activation on the final layer (identity function)
#     495     y = self.layers[-1](y)
#     496 else:
#     497     # If classification, apply the final layer activation (e.g., Softmax, Sigmoid)
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# array([0.76325758, 0.75737393, 0.77255639, 0.76091082, 0.74664107])

# %%
TestSetAssessor("f1")(model, dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 TestSetAssessor("f1")(model, dataset)
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/models/assessment/methods.py:329, in TestSetAssessor.__call__(self, model, ds, save, parameters, monitor, **kwargs)
#     327 # fit model
#     328 ind_estimator = model.loadEstimator(evalparams)
# --> 329 ind_estimator = model.fit(
#     330     X, y, ind_estimator, self.mode, monitor=monitor, **kwargs
#     331 )
#     332 # predict values for independent test set
#     333 if model.task.isRegression() or not self.useProba:
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/models/early_stopping.py:184, in early_stopping.<locals>.wrapper_fit(self, X, y, estimator, mode, split, monitor, **kwargs)
#     179 assert self.supportsEarlyStopping, (
#     180     "early_stopping decorator can only be used for models that support"
#     181     " early stopping."
#     182 )
#     183 self.earlyStopping.mode = mode if mode is not None else self.earlyStopping.mode
# --> 184 estimator, best_epoch = func(
#     185     self, X, y, estimator, mode, split, monitor, **kwargs
#     186 )
#     187 if self.earlyStopping.mode == EarlyStoppingMode.RECORDING:
#     188     self.earlyStopping.recordEpochs(best_epoch + 1)  # +1 for 0-indexing
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/extra/gpu/models/dnn.py:277, in DNNModel.fit(self, X, y, estimator, mode, split, monitor, **kwargs)
#     273 train_index, val_index = next(split.split(X, y))
#     274 monitor.onFitStart(
#     275     self, X[train_index, :], y[train_index], X[val_index, :], y[val_index]
#     276 )
# --> 277 estimator_fit = estimator.fit(
#     278     X[train_index, :],
#     279     y[train_index],
#     280     X[val_index, :],
#     281     y[val_index],
#     282     monitor=monitor,
#     283     **kwargs,
#     284 )
#     285 monitor.onFitEnd(estimator_fit[0], estimator_fit[1])
#     286 return estimator_fit
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/extra/gpu/models/neural_network.py:164, in Base.fit(self, X_train, y_train, X_valid, y_valid, monitor)
#     162         loss = self.criterion(y_, yb)
#     163     loss.backward()
# --> 164     optimizer.step()
#     165     monitor.onBatchEnd(i, float(loss))
#     166 if patience == -1:
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/optimizer.py:391, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     386         else:
#     387             raise RuntimeError(
#     388                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     389             )
# --> 391 out = func(*args, **kwargs)
#     392 self._optimizer_step_code()
#     394 # call optimizer step post hooks
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/adamw.py:188, in AdamW.step(self, closure)
#     175     beta1, beta2 = group["betas"]
#     177     has_complex = self._init_group(
#     178         group,
#     179         params_with_grad,
#    (...)
#     185         state_steps,
#     186     )
# --> 188     adamw(
#     189         params_with_grad,
#     190         grads,
#     191         exp_avgs,
#     192         exp_avg_sqs,
#     193         max_exp_avg_sqs,
#     194         state_steps,
#     195         amsgrad=amsgrad,
#     196         beta1=beta1,
#     197         beta2=beta2,
#     198         lr=group["lr"],
#     199         weight_decay=group["weight_decay"],
#     200         eps=group["eps"],
#     201         maximize=group["maximize"],
#     202         foreach=group["foreach"],
#     203         capturable=group["capturable"],
#     204         differentiable=group["differentiable"],
#     205         fused=group["fused"],
#     206         grad_scale=getattr(self, "grad_scale", None),
#     207         found_inf=getattr(self, "found_inf", None),
#     208         has_complex=has_complex,
#     209     )
#     211 return loss
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/adamw.py:340, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     337 else:
#     338     func = _single_tensor_adamw
# --> 340 func(
#     341     params,
#     342     grads,
#     343     exp_avgs,
#     344     exp_avg_sqs,
#     345     max_exp_avg_sqs,
#     346     state_steps,
#     347     amsgrad=amsgrad,
#     348     beta1=beta1,
#     349     beta2=beta2,
#     350     lr=lr,
#     351     weight_decay=weight_decay,
#     352     eps=eps,
#     353     maximize=maximize,
#     354     capturable=capturable,
#     355     differentiable=differentiable,
#     356     grad_scale=grad_scale,
#     357     found_inf=found_inf,
#     358     has_complex=has_complex,
#     359 )
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/optim/adamw.py:420, in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, has_complex)
#     418 # Decay the first and second moment running average coefficient
#     419 exp_avg.lerp_(grad, 1 - beta1)
# --> 420 exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     422 if capturable or differentiable:
#     423     step = step_t
#
# KeyboardInterrupt:

# %%
display(model.estimator.get_params())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 display(model.estimator.get_params())
#
# AttributeError: 'str' object has no attribute 'get_params'

# %%
model.loadEstimatorFromFile(model_sts )
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 model.loadEstimatorFromFile(model_sts.get_params() )
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/extra/gpu/models/dnn.py:205, in DNNModel.loadEstimatorFromFile(self, params, fallback_load)
#     203 # load states if available
#     204 if os.path.exists(path):
# --> 205     estimator.load_state_dict(torch.load(path))
#     206 elif not fallback_load:
#     207     raise FileNotFoundError(
#     208         f"No estimator found at {path}, "
#     209         f"loading estimator weights from file failed."
#     210     )
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/serialization.py:1040, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1038     except RuntimeError as e:
#    1039         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1040 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/torch/serialization.py:1262, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1256 if not hasattr(f, 'readinto') and (3, 8, 0) <= sys.version_info < (3, 8, 2):
#    1257     raise RuntimeError(
#    1258         "torch.load does not work with file-like objects that do not implement readinto on Python 3.8.0 and 3.8.1. "
#    1259         f"Received object of type \"{type(f)}\". Please update to Python 3.8.2 or newer to restore this "
#    1260         "functionality.")
# -> 1262 magic_number = pickle_module.load(f, **pickle_load_args)
#    1263 if magic_number != MAGIC_NUMBER:
#    1264     raise RuntimeError("Invalid magic number; corrupt file?")
#
# UnpicklingError: pickle data was truncated

# %%
display(model.nClass)
display(type(model.estimator))
display(model.estimator)
# Out:
# 2
# str
# 'Uninitialized model.'

# %%
CrossValAssessor("f1")(model, dataset)
# Out:
# array([0.76325758, 0.75737393, 0.77255639, 0.76091082, 0.74664107])

# %%
TestSetAssessor("f1")(model, dataset)
# Out:
# array([0.76021588])

# %%
model.fit(dataset.X, dataset.y, estimator=model_sts)
# Out:
# STFullyConnected(
#   (layers): ModuleList(
#     (0): Linear(in_features=2048, out_features=200, bias=True)
#     (1): Linear(in_features=200, out_features=100, bias=True)
#     (2): Linear(in_features=100, out_features=1, bias=True)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (fc0): Linear(in_features=2048, out_features=256, bias=True)
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=1, bias=True)
#   (criterion): BCELoss()
#   (final_layer_activation): Sigmoid()
# )
