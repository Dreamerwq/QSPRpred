# %%
import os
import qsprpred

from qsprpred.data import QSPRDataset, RandomSplit
from qsprpred.data.descriptors.fingerprints import MorganFP
import pandas as pd
# Out:
# /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages/xgboost/core.py:377: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc >= 2.28) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
os.makedirs("dataset_outputs/hERG/data", exist_ok=True)

# Create dataset
dataset = QSPRDataset.fromTableFile(
    filename="data/src/datasets/hiv/data/HIV.csv",
    store_dir="dataset_outputs/HIV/data",
    name="HIVDataset",
    target_props=[{"name": "Y", "task": "SINGLECLASS", "th": [0.5]}],
    random_state=42,
    smiles_col = 'Drug',
    sep=','
)

# %%
dataset.getDF()
# Out:
#                       Y                                               Drug  \
# QSPRID
# HIVDataset_00000  False  CCC1=[O+][Cu-3]2([O+]=C(CC)C1)[O+]=C(CC)CC(CC)...
# HIVDataset_00001  False  C(=Cc1ccccc1)C1=[O+][Cu-3]2([O+]=C(C=Cc3ccccc3...
# HIVDataset_00002  False                   CC(=O)N1c2ccccc2Sc2c1ccc1ccccc21
# HIVDataset_00003  False    Nc1ccc(C=Cc2ccc(N)cc2S(=O)(=O)O)c(S(=O)(=O)O)c1
# HIVDataset_00004  False                             O=S(=O)(O)CCS(=O)(=O)O
# ...                 ...                                                ...
# HIVDataset_40665  False  CCC1CCC2c3c([nH]c4ccc(C)cc34)C3C(=O)N(N(C)C)C(...
# HIVDataset_40666  False  Cc1ccc2[nH]c3c(c2c1)C1CCC(C(C)(C)C)CC1C1C(=O)N...
# HIVDataset_40667  False  Cc1ccc(N2C(=O)C3c4[nH]c5ccccc5c4C4CCC(C(C)(C)C...
# HIVDataset_40668  False  Cc1cccc(N2C(=O)C3c4[nH]c5ccccc5c4C4CCC(C(C)(C)...
# HIVDataset_40669  False  CCCCCC=C(c1cc(Cl)c(OC)c(-c2nc(C)no2)c1)c1cc(Cl...
#
#                             QSPRID  Y_original
# QSPRID
# HIVDataset_00000  HIVDataset_00000           0
# HIVDataset_00001  HIVDataset_00001           0
# HIVDataset_00002  HIVDataset_00002           0
# HIVDataset_00003  HIVDataset_00003           0
# HIVDataset_00004  HIVDataset_00004           0
# ...                            ...         ...
# HIVDataset_40665  HIVDataset_40665           0
# HIVDataset_40666  HIVDataset_40666           0
# HIVDataset_40667  HIVDataset_40667           0
# HIVDataset_40668  HIVDataset_40668           0
# HIVDataset_40669  HIVDataset_40669           0
#
# [40670 rows x 4 columns]

# %%
dataset.prepareDataset(
    split=RandomSplit(test_fraction=0.2, dataset=dataset),
    feature_calculators=[MorganFP(radius=3, nBits=2048)],
    recalculate_features=True,
)

# %%
from qsprpred.data.descriptors.sets import RDKitDescs

rdkit_descs = RDKitDescs()

dataset.addDescriptors([rdkit_descs])

dataset.descriptorSets
# Out:
# /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:133: RuntimeWarning: overflow encountered in cast
#   return arr.astype(dtype, copy=True)
# [<qsprpred.data.descriptors.fingerprints.MorganFP at 0x7f6738b59790>,
#  <qsprpred.data.descriptors.sets.RDKitDescs at 0x7f6733bda4d0>]

# %%
# Přidejte cestu k vašemu lokálnímu repozitáři
import sys
import os

# Přidání cesty k lokálnímu repozitáři na začátek sys.path
sys.path.insert(0, '/home/ubuntu/Bakalarka/QSPRpred')

# Zkontrolujte, zda je cesta v sys.path
print(sys.path)

from importlib import reload

# Znovu proveďte import
from qsprpred.extra.gpu.models.neural_network import STFullyConnected
# Znovu načtěte modul, abyste zajistili, že je správně importován
reload(sys.modules['qsprpred.extra.gpu.models.neural_network'])

# Znovu proveďte import
from qsprpred.extra.gpu.models.neural_network import STFullyConnected

os.chdir('/home/ubuntu/Bakalarka/QSPRpred')
print(os.getcwd())


import sys
import importlib.util

# Přidání cesty k repozitáři do sys.path
sys.path.insert(0, '/home/ubuntu/Bakalarka/QSPRpred')

# Specifikujte cestu k souboru, který chcete importovat
module_path = '/home/ubuntu/Bakalarka/QSPRpred/qsprpred/extra/gpu/models/neural_network.py'
module_name = 'qsprpred.extra.gpu.models.neural_network'

# Načtěte modul z konkrétní cesty
spec = importlib.util.spec_from_file_location(module_name, module_path)
neural_network = importlib.util.module_from_spec(spec)
spec.loader.exec_module(neural_network)

# Nyní můžete používat třídu STFullyConnected
STFullyConnected = neural_network.STFullyConnected
# Out:
# ['/home/ubuntu/Bakalarka/QSPRpred', '/home/ubuntu/miniconda3/envs/bakalarka_env/lib/python311.zip', '/home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11', '/home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/lib-dynload', '', '/home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages']
# /home/ubuntu/Bakalarka/QSPRpred
# lol

# %%
from sklearn.model_selection import ParameterGrid
from torch.nn import functional as F
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
import pandas as pd
def test_fun(dic,  X_train, y_train, X_test, y_test) -> pd.DataFrame:
    param_grid_t = ParameterGrid(dic)
    i = 0
    val_f1_t = []
    val_acc_t = []
    param_len_t = len(param_grid_t)
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print("Device used:", device)
    for param in param_grid_t:
        i += 1
        print(i, '/', param_len_t)
        model_sts_t = STFullyConnected(n_dim=X_train.shape[1],  # počet vstupních neuronů (počet deskriptorů)
        n_class=1,  # regresní úloha (1 výstup)
        gpus=[],
        device=device,
        is_reg=False, **param)
        model_sts_t.fit(X_train, y_train)
        res = model_sts_t.predict(X_test)
        res = res >0.5
        val_f1_t.append(f1_score(res, y_test))
        val_acc_t.append(accuracy_score(res, y_test))
        print(param)
        print(f1_score(res, y_test))
        print(accuracy_score(res, y_test))
    my_df = pd.DataFrame(param_grid_t)
    my_df["F1"] = val_f1_t
    my_df["Acc"] = val_acc_t
    return my_df

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

X = dataset.X
X1, X2, y1, y2 = train_test_split(dataset.X, dataset.y, test_size=0.25, random_state=42)
X3 = dataset.X_ind
y3 = dataset.y_ind

imp_mean = SimpleImputer(missing_values=pd.NA, strategy='mean')
X1 = imp_mean.fit_transform(X1)
X2 = imp_mean.transform(X2)
X3 = imp_mean.transform(X3)

scaler = StandardScaler()
X1 = scaler.fit_transform(X1)
X2 = scaler.transform(X2)
X3 = scaler.transform(X3)
# Out:
# /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages/numpy/core/_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages/sklearn/impute/_base.py:565: UserWarning: Skipping features without any observed values: ['RDkit_Ipc']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages/sklearn/impute/_base.py:565: UserWarning: Skipping features without any observed values: ['RDkit_Ipc']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/ubuntu/miniconda3/envs/bakalarka_env/lib/python3.11/site-packages/sklearn/impute/_base.py:565: UserWarning: Skipping features without any observed values: ['RDkit_Ipc']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
dataset.getDF()["Y"].count()
# Out:
# 40670

# %%
test_par = {'weight_decay': 0.0001, 'patience': 50, 
            'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4],
            'n_epochs': 200, 'dropout_frac': 0.5,
            'act_fun': F.selu}
model_sts_3 = STFullyConnected(n_dim=X1.shape[1],  # počet vstupních neuronů (počet deskriptorů)
    n_class=1,  # regresní úloha (1 výstup)
    gpus=[],
    device="cuda",
    batch_size=256,is_reg=False, **test_par)
model_sts_3.fit(X1, y1)
res = model_sts_3.predict(X2)
res = res >0.5
print(f1_score(res, dataset.y_ind))
#{'act_fun': <function selu at 0x7f90c22cd760>, 'batch_size': 256, 'dropout_frac': 0, 'n_epochs': 400, 'neuron_layers': [2256], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
#0.38620689655172413
#0.9452913695598721
#{'act_fun': <function selu at 0x7f90c22cd760>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
#0.39944521497919555
#0.9467666584706171
# Out:
# 0.014563106796116505

# %%
from torch import optim
import torch
my_dict_ult = {
    "act_fun": [F.selu],
    "dropout_frac": [0.4, 0.5, 0.6],
    "patience": [75],
    "tol": [1e-5],
    "weight_decay": [1e-4],
    "n_epochs": [200,300, 400],
    "neuron_layers": [ [ 1024, 512, 256, 128, 64, 32, 16, 8, 4], [4096, 2048], [7500, 3750, 1250], [7500, 3750], [2048]]
    , "batch_size": [256]
    , "optimizer": [optim.AdamW] 
}
df_batch_ult = test_fun(my_dict_ult, X1, y1, X2, y2)
# Out:
# Device used: cuda
# 1 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3971631205673759
# 0.9686501106466683
# 2 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [4096, 2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3490759753593429
# 0.961027784607819
# 3 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [7500, 3750, 1250], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.2986111111111111
# 0.9503319400049176
# 4 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [7500, 3750], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.31800766283524906
# 0.9562330956478977
# 5 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 200, 'neuron_layers': [2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3931203931203931
# 0.969633636587165
# 6 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 300, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3963963963963964
# 0.9670518809933611
# 7 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 300, 'neuron_layers': [4096, 2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3079777365491651
# 0.9541431030243422
# 8 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 300, 'neuron_layers': [7500, 3750, 1250], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3050847457627119
# 0.9495942955495451
# 9 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 300, 'neuron_layers': [7500, 3750], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.30604982206405695
# 0.9520531104007868
# 10 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 300, 'neuron_layers': [2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.38974358974358975
# 0.9707401032702238
# 11 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 400, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.35714285714285715
# 0.962380132776002
# 12 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 400, 'neuron_layers': [4096, 2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.2994652406417112
# 0.9516842881731006
# 13 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 400, 'neuron_layers': [7500, 3750, 1250], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3053173241852487
# 0.9502089992623556
# 14 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 400, 'neuron_layers': [7500, 3750], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3093145869947276
# 0.9516842881731006
# 15 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.4, 'n_epochs': 400, 'neuron_layers': [2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3949367088607595
# 0.9706171625276616
# 16 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.39276485788113696
# 0.9711089254979101
# 17 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 200, 'neuron_layers': [4096, 2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3514644351464435
# 0.9618883698057537
# 18 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 200, 'neuron_layers': [7500, 3750, 1250], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3010752688172043
# 0.9520531104007868
# 19 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 200, 'neuron_layers': [7500, 3750], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.31721470019342357
# 0.956601917875584
# 20 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 200, 'neuron_layers': [2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3931203931203931
# 0.969633636587165
# 21 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 300, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.40189125295508277
# 0.9688959921317924
# 22 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 300, 'neuron_layers': [4096, 2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.31401869158878504
# 0.9548807474797147
# 23 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 300, 'neuron_layers': [7500, 3750, 1250], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.303236797274276
# 0.9497172362921072
# 24 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 300, 'neuron_layers': [7500, 3750], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3041144901610018
# 0.9521760511433489
# 25 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 300, 'neuron_layers': [2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.38974358974358975
# 0.9707401032702238
# 26 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 400, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.4018058690744921
# 0.9674207032210475
# 27 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 400, 'neuron_layers': [4096, 2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.2990990990990991
# 0.9521760511433489
# 28 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 400, 'neuron_layers': [7500, 3750, 1250], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.29982964224872233
# 0.9494713548069831
# 29 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 400, 'neuron_layers': [7500, 3750], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.30823117338003503
# 0.9514384066879764
# 30 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.5, 'n_epochs': 400, 'neuron_layers': [2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3949367088607595
# 0.9706171625276616
# 31 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 200, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.03663003663003663
# 0.9676665847061716
# 32 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 200, 'neuron_layers': [4096, 2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3574468085106383
# 0.9628718957462503
# 33 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 200, 'neuron_layers': [7500, 3750, 1250], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3151969981238274
# 0.9551266289648389
# 34 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 200, 'neuron_layers': [7500, 3750], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3234714003944773
# 0.9578313253012049
# 35 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 200, 'neuron_layers': [2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3931203931203931
# 0.969633636587165
# 36 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 300, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3188405797101449
# 0.9711089254979101
# 37 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 300, 'neuron_layers': [4096, 2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3218390804597701
# 0.9564789771330219
# 38 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 300, 'neuron_layers': [7500, 3750, 1250], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3018867924528302
# 0.9499631177772314
# 39 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 300, 'neuron_layers': [7500, 3750], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.30685920577617326
# 0.9527907548561594
# 40 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 300, 'neuron_layers': [2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.38974358974358975
# 0.9707401032702238
# 41 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 400, 'neuron_layers': [1024, 512, 256, 128, 64, 32, 16, 8, 4], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.38242894056847543
# 0.9706171625276616
# 42 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 400, 'neuron_layers': [4096, 2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.30347349177330896
# 0.9531595770838456
# 43 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 400, 'neuron_layers': [7500, 3750, 1250], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.29591836734693877
# 0.9491025325792968
# 44 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 400, 'neuron_layers': [7500, 3750], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.30687830687830686
# 0.9516842881731006
# 45 / 45
# {'act_fun': <function selu at 0x7f67334294e0>, 'batch_size': 256, 'dropout_frac': 0.6, 'n_epochs': 400, 'neuron_layers': [2048], 'optimizer': <class 'torch.optim.adamw.AdamW'>, 'patience': 75, 'tol': 1e-05, 'weight_decay': 0.0001}
# 0.3949367088607595
# 0.9706171625276616

# %%
df_batch_ult.sort_values(by="F1", ascending=False, inplace=True)
df_batch_ult.to_csv('qsprpred/extra/gpu/models/dataset_outputs/HIV/tabs/hivbatch1.csv')
