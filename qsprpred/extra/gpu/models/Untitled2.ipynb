# %%
import os

from IPython.display import display
from qsprpred.extra.gpu.models.neural_network import STFullyConnected

from qsprpred.data import QSPRDataset, RandomSplit
from qsprpred.data.descriptors.fingerprints import MorganFP

os.makedirs("tutorial_output/data", exist_ok=True)


# Create dataset
dataset = QSPRDataset.fromTableFile(
    filename="data/src/datasets/hiv/data/HIV.csv",
    store_dir="tutorial_output/data",
    name="MonitoringTutorialDataset",
    target_props=[{"name": "Y", "task": "SINGLECLASS", 'th': 'precomputed'}],
    random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 13
#       9 os.makedirs("tutorial_output/data", exist_ok=True)
#      12 # Create dataset
# ---> 13 dataset = QSPRDataset.fromTableFile(
#      14     filename="data/src/datasets/hiv/data/HIV.csv",
#      15     store_dir="tutorial_output/data",
#      16     name="MonitoringTutorialDataset",
#      17     random_state=42
#      18 )
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/data/tables/qspr.py:193, in QSPRDataset.fromTableFile(name, filename, sep, *args, **kwargs)
#     180 @staticmethod
#     181 def fromTableFile(name: str, filename: str, sep: str = "\t", *args, **kwargs):
#     182     r"""Create QSPRDataset from table file (i.e. CSV or TSV).
#     183
#     184     Args:
#    (...)
#     191         QSPRDataset: `QSPRDataset` object
#     192     """
# --> 193     return QSPRDataset(
#     194         name,
#     195         df=pd.read_table(filename, sep=sep),
#     196         *args,  # noqa: B026 # FIXME: this is a bug in flake8...
#     197         **kwargs,
#     198     )
#
# File ~/DataspellProjects/Bakalarka/QSPRpred/qsprpred/data/tables/qspr.py:150, in QSPRDataset.__init__(self, name, target_props, df, smiles_col, add_rdkit, store_dir, overwrite, n_jobs, chunk_size, drop_invalids, drop_empty, index_cols, autoindex_name, random_state, store_format)
#     146     target_props = [
#     147         TargetProperty.fromJSON(json.dumps(x)) for x in target_props
#     148     ]
#     149 elif target_props is None:
# --> 150     raise ValueError(
#     151         "Target properties must be specified for a new QSPRDataset."
#     152     )
#     153 # load names of descriptors to use as training features
#     154 self.featureNames = self.getFeatureNames()
#
# ValueError: Target properties must be specified for a new QSPRDataset.
